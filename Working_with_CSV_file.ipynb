# %%
import pandas as pd

# %%
df = pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv',index_col=	'Rank')

# %%
df.head(5)
# Out:
#           Country  Cost of Living Index  Rent Index  \
# Rank
# 1     Switzerland                 101.1        46.5
# 2         Bahamas                  85.0        36.7
# 3         Iceland                  83.0        39.2
# 4       Singapore                  76.7        67.2
# 5        Barbados                  76.6        19.0
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# Rank
# 1                               74.9            109.1                    97.0
# 2                               61.8             81.6                    83.3
# 3                               62.0             88.4                    86.8
# 4                               72.1             74.6                    50.4
# 5                               48.9             80.8                    69.4
#
#       Local Purchasing Power Index
# Rank
# 1                            158.7
# 2                             54.6
# 3                            120.3
# ...

# %%
#import requests
#from io import StringIO
#import pandas as pd

#url = "https://example.com/data.csv"  # Replace with your actual URL
#headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
#req = requests.get(url, headers=headers)
#data = StringIO(req.text)

#df = pd.read_csv(data)

# %%
pd.read_csv('Cost_of_Living_Index_by_Country_2024.csv',skiprows=[])
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Switzerland                 101.1        46.5
# 1       2      Bahamas                  85.0        36.7
# 2       3      Iceland                  83.0        39.2
# 3       4    Singapore                  76.7        67.2
# 4       5     Barbados                  76.6        19.0
# ..    ...          ...                   ...         ...
# 116   117   Bangladesh                  22.5         2.4
# 117   118        India                  21.2         5.6
# 118   119        Egypt                  21.0         3.7
# 119   120        Libya                  20.4         4.3
# 120   121     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# ...

# %%
pd.read_csv('zomato.csv',encoding='Latin=1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
#pd.read_csv('zomato.csv',sep=';',encoding='Latin=1',error_bad_lines=False)

# %%
pd.read_csv('zomato.csv',encoding='Latin=1',error_bad_lines=False)
# Out:
# /var/folders/91/g785j1hx1z51cmj4tx83q0nw0000gn/T/ipykernel_48098/516369347.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('zomato.csv',encoding='Latin=1',error_bad_lines=False)
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# ...

# %%
dfs = pd.read_csv('zomato.csv',encoding='Latin=1',chunksize=500)
for chunks in dfs:
    print(chunks.size)
# Out:
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 10500
# 1071

# %%
dff = pd.read_json('us-states.json')

# %%
dfu = pd.read_json('https://www.floatrates.com/daily/usd.json')

# %%
dfu
# Out:
#                                       aud                           cad  \
# code                                  AUD                           CAD
# alphaCode                             AUD                           CAD
# numericCode                           036                           124
# name                    Australian Dollar               Canadian Dollar
# rate                             1.519683                      1.373738
# date         Fri, 9 Aug 2024 23:59:00 GMT  Fri, 9 Aug 2024 23:59:00 GMT
# inverseRate                      0.658032                      0.727941
#
#                                       cny                           eur  \
# code                                  CNY                           EUR
# alphaCode                             CNY                           EUR
# numericCode                           156                           978
# name                         Chinese Yuan                          Euro
# ...
